# %% [markdown]
# let see how github works
# it my first work

# %%
for x in range (1, 100):
    x = x % 3
    if x // 3 == 0:
        print('my word', x)
# Out:
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# my word 0
# my word 1
# my word 2
# ...
